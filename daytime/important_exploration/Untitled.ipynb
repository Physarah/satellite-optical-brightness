# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
stuff = pd.read_csv("/Users/physarah/Desktop/good_satellite_data_final_set.csv")

# %%
stuff.columns
# Out:
# Index(['Unnamed: 0.4', 'Unnamed: 0.3', 'Unnamed: 0.2', 'Unnamed: 0.1',
#        'Unnamed: 0', 'source_mean', 'source_median', 'source_sum',
#        'source_rate', 'sky_mean', 'sky_median', 'sky_sum', 'sky_rate',
#        'target_mean', 'target_median', 'target_sum', 'target_rate', 'sc_area',
#        'bk_area', 'exposure_time', 'datetimes_sat', 'gains_sat', 'airmass',
#        'm_inst', 'm_inst_sky', 'calibed_mags', 'altitude', 'azimuth', 'utc',
#        'zenith_angle', 'km_distance', 'sunsep', 'sat_name', 'norad_id',
#        'v_type', 'tle_filename', 'tle1', 'tle2', 'tle3', 'altitude2',
#        'azimuth2', 'forest_time', 'line_distance', 'sat_height', 'longitude',
#        'latitude', 'sun_alt', 'sun_az', 'forrest_magnitudes'],
#       dtype='object')

# %%
final_dataframe_v15 = stuff[stuff['v_type']=='V1.5']
final_dataframe_v1 = stuff[stuff['v_type']=='V1.0']
final_dataframe_v2 = stuff[stuff['v_type']=='V2.0 mini']

# %%
#plt.scatter(final_dataframe_v15['zenith_angle'], final_dataframe_v15['calibed_mags'])
plt.scatter(stuff['latitude'], 
            stuff['longitude'],
           c = stuff['calibed_mags'])
plt.colorbar()
#plt.scatter(final_dataframe_v1['zenith_angle'], final_dataframe_v1['calibed_mags'])

#plt.ylim(6,1)

# %%
plt.scatter(stuff['altitude'], 
            stuff['azimuth'],
           c = stuff['calibed_mags'], s = 10, cmap = 'plasma_r')
plt.colorbar()
plt.clim(3,6)

# %%
final_dataframe_v1
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.5, Unnamed: 0.4, Unnamed: 0.3, Unnamed: 0.2, Unnamed: 0.1, Unnamed: 0, source_mean, source_median, source_sum, source_rate, sky_mean, sky_median, sky_sum, sky_rate, target_mean, target_median, target_sum, target_rate, sc_area, bk_area, exposure_time, datetimes_sat, gains_sat, airmass, m_inst, m_inst_sky, calibed_mags, altitude, azimuth, utc, zenith_angle, km_distance, sunsep, sat_name, norad_id, v_type, tle_filename, tle1, tle2, tle3, altitude2, azimuth2, forest_time, line_distance, sat_height, longitude, latitude, forrest_magnitudes_lambertian_09, forrest_magnitudes_green, forrest_magnitudes, sun_alt, sun_az, updated_prediction_mag, updated_pred_mag]
# Index: []
#
# [0 rows x 54 columns]
